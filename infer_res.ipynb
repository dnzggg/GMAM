# %%
# an example for the inference on the essay test dataset

from fastNLP import cache_results

_first = False
bart_name = "facebook/bart-base"
dataset_name='essay'
cache_fn = f"caches/data_{bart_name}_{dataset_name}_{_first}.pt"

if 'essay' in dataset_name:
    from data.pipe import BartAMPipe_essay as BartPipe
    from model.metrics import Seq2SeqSpanMetric_essay as Seq2SeqSpanMetric
elif 'cdcp' in dataset_name:
    from data.pipe import BartAMPipe_cdcp as BartPipe
    from model.metrics import Seq2SeqSpanMetric_cdcp as Seq2SeqSpanMetric

# %%
import pickle

test_res = pickle.load(open("./test_batch.pkl",'rb'))

# %%
# prepare tokenizer and metirc
@cache_results(cache_fn, _refresh=False)
def get_data():
    pipe = BartPipe(tokenizer=bart_name, _first=_first)
    data_bundle = pipe.process_from_file(f'./data/{dataset_name}', demo=False)
    return data_bundle, pipe.tokenizer, pipe.mapping2id, pipe.mapping2targetid , pipe.relation_ids, pipe.component_ids, pipe.none_ids

data_bundle, tokenizer, mapping2id, mapping2targetid,relation_ids,component_ids,none_ids = get_data()
bos_token_id = 0  #
eos_token_id = 1  #
# tag_labels = model.seq2seq_model.decoder.mapping.tolist()

label_ids = list(mapping2id.values())
print(label_ids)
# tag_tokens = tokenizer.convert_ids_to_tokens(tag_labels)

# essay dataset setting
mapping = {'<s>': 0, '</s>': 1, '<<positive>>': 2, '<<negative>>': 3, '<<none>>': 4, '<<MC>>': 5, '<<C>>': 6, '<<P>>': 7}

metric = Seq2SeqSpanMetric(eos_token_id, num_labels=len(label_ids),label_mapping = mapping ,_first=_first,)
# Out:
# Read cache from caches/data_facebook/bart-base_essay_False.pt.
# [50265, 50266, 50267, 50268, 50269, 50270]

# %%
input_batch = test_res['input_batch'][0]
output_batch = test_res['output_batch'][0]

# %%
print(input_batch['batch_y']['tgt_tokens'])
# Out:
# tensor([[  0, 241, 256,  ...,   1,   1,   1],
#         [  0,  14,  22,  ...,   1,   1,   1],
#         [  0, 204, 225,  ...,   1,   1,   1],
#         ...,
#         [  0,  23,  42,  ...,   1,   1,   1],
#         [  0,  13,  30,  ...,   1,   1,   1],
#         [  0, 117, 129,  ...,   1,   1,   1]])

# %%
for sample_id,(src_token,pred,target) in enumerate(zip(input_batch['batch_x']['src_tokens'],output_batch['batch_res']['pred'],input_batch['batch_y']['tgt_tokens'])):
    print("ID{}".format(sample_id))
    tokens = tokenizer.convert_ids_to_tokens(src_token)
    # use metric to convert sequence to spans
    ps,_ = metric.build_pair(pred.tolist())
    ts,_ = metric.build_pair(target.tolist())
    
    # preds 
    print("----------prediction results----------")
    for tup in ps:
        # sent1 target
        # sent2 src
        sent1 = tokenizer.convert_tokens_to_string(tokens[tup[0]-len(metric.id2label):tup[1]-len(metric.id2label)+1])
        lab1 = metric.id2label[tup[2]]
        sent2 = tokenizer.convert_tokens_to_string(tokens[tup[3]-len(metric.id2label):tup[4]-len(metric.id2label)+1])
        lab2 = metric.id2label[tup[5]]
        rel = metric.id2label[tup[6]]
        print('target:',sent1)
        print('source:',sent2)
        print(lab1,lab2,rel)
        
    print("----------target results----------")
    for tup in ts:
        sent1 = tokenizer.convert_tokens_to_string(tokens[tup[0]-len(metric.id2label):tup[1]-len(metric.id2label)+1])
        lab1 = metric.id2label[tup[2]]
        sent2 = tokenizer.convert_tokens_to_string(tokens[tup[3]-len(metric.id2label):tup[4]-len(metric.id2label)+1])
        lab2 = metric.id2label[tup[5]]
        rel = metric.id2label[tup[6]]
        print('target:',sent1)
        print('source:',sent2)
        print(lab1,lab2,rel)
# Out:
# ID0
# ----------prediction results----------
# (241, 256, 6, 34, 50, 7, 2)
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: Seeingnationalflagsbehonoredmaybethemostemotionalmomentstoeachath
# <<C>> <<P>> <<positive>>
# (241, 256, 6, 53, 79, 7, 2)
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: Theathletealsoseemstobemoreawareofhisresponsibilitiesandhewantstocontributemoretohisbelovedcountry
# <<C>> <<P>> <<positive>>
# (241, 256, 6, 81, 107, 7, 2)
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: Whenwitnessingournationalflagsflyingproudlyamongothers,manyofuscanstophidingourprideandh
# <<C>> <<P>> <<positive>>
# (241, 256, 6, 113, 144, 7, 2)
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: whenVietnambecamethechampionofSEAGAMESforthefirsttimein2008,afestivalatmospherepermeatedintothestre
# <<C>> <<P>> <<positive>>
# (241, 256, 6, 147, 176, 7, 2)
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: Peoplefromallagesturnedouttothestreetswithflags,bannersandtheysangaloudsongsofHoChiMinhPresident
# <<C>> <<P>> <<positive>>
# (241, 256, 6, 178, 188, 7, 2)
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: Theeageratmospherelastedmanynextdays
# <<C>> <<P>> <<positive>>
# (241, 256, 6, 193, 215, 7, 2)
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: somehooligansweresoexcitedthattheytookpartinmotorracingorusingfireworksil
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: Seeingnationalflagsbehonoredmaybethemostemotionalmomentstoeachath
# <<C>> <<P>> <<positive>>
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: Theathletealsoseemstobemoreawareofhisresponsibilitiesandhewantstocontributemoretohisbelovedcountry
# <<C>> <<P>> <<positive>>
# target: sporteventshelptowakeuploveandresponsibilitiesstronglyineachc
# source: Whenwitnessingournationalflagsflyingproudlyamongothers,manyofuscanstophidingourprideandh
# <<C>> <<P>> <<positive>>
# target: Whenwitnessingournationalflagsflyingproudlyamongothers,manyofuscanstophidingourprideandh
# source: whenVietnambecamethechampionofSEAGAMESforthefirsttimein2008,afestivalatmospherepermeatedintothestre
# <<P>> <<P>> <<positive>>
# target: Whenwitnessingournationalflagsflyingproudlyamongothers,manyofuscanstophidingourprideandh
# source: Peoplefromallagesturnedouttothestreetswithflags,bannersandtheysangaloudsongsofHoChiMinhPresident
# <<P>> <<P>> <<positive>>
# target: Whenwitnessingournationalflagsflyingproudlyamongothers,manyofuscanstophidingourprideandh
# source: Theeageratmospherelastedmanynextdays
# <<P>> <<P>> <<positive>>
# target: Whenwitnessingournationalflagsflyingproudlyamongothers,manyofuscanstophidingourprideandh
# source: somehooligansweresoexcitedthattheytookpartinmotorracingorusingfireworksil
# <<P>> <<P>> <<negative>>
# target: somehooligansweresoexcitedthattheytookpartinmotorracingorusingfireworksil
# source: thehooligansonlytookaminorityofpeople
# <<P>> <<P>> <<negative>>
# ID1
# ----------prediction results----------
# (14, 22, 6, 57, 80, 7, 2)
# target: keepingowncustomsstablymightcausediscrimination
# source: Thelocalpeoplemayalsoregardthemasaspecialgroupaswellandseparatethemfromthemain-streamsoc
# <<C>> <<P>> <<positive>>
# (14, 22, 6, 89, 98, 7, 2)
# target: keepingowncustomsstablymightcausediscrimination
# source: theChineseimmigrantsinIndonesiain1969
# <<C>> <<P>> <<positive>>
# (14, 22, 6, 100, 113, 7, 2)
# target: keepingowncustomsstablymightcausediscrimination
# source: TheyformedChinatownandkeptChineselanguageandcustomsinit
# <<C>> <<P>> <<positive>>
# (14, 22, 6, 115, 139, 7, 2)
# target: keepingowncustomsstablymightcausediscrimination
# source: WhiletheIndonesiansstoppedworkingat4:00pmandwenthomeforrest,Chineseimmigrantswerestillworking
# <<C>> <<P>> <<positive>>
# (14, 22, 6, 142, 153, 7, 2)
# target: keepingowncustomsstablymightcausediscrimination
# source: beingmuchricherthanlocalpeople,theyfacedthediscrimination
# <<C>> <<P>> <<positive>>
# (14, 22, 6, 155, 165, 7, 2)
# target: keepingowncustomsstablymightcausediscrimination
# source: Theirhousesandprivatecarswereburiedbylocalpeople
# <<C>> <<P>> <<positive>>
# (155, 165, 7, 168, 189, 7, 2)
# target: Theirhousesandprivatecarswereburiedbylocalpeople
# source: thelocalswerejealousofChinesepeople,whohadsomuchwealth,whichshouldhavebeentheirs
# <<P>> <<P>> <<positive>>
# (14, 22, 6, 191, 229, 7, 2)
# target: keepingowncustomsstablymightcausediscrimination
# source: IftheChineseimmigrantshadfollowedthelocalcustomsandassimilatedintoIndonesia,theywouldnothavebeenregardsasagroupofChineseanddiscriminationmighthavebeenal
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: keepingowncustomsstablymightcausediscrimination
# source: Thelocalpeoplemayalsoregardthemasaspecialgroupaswellandseparatethemfromthemain-streamsoc
# <<C>> <<P>> <<positive>>
# target: keepingowncustomsstablymightcausediscrimination
# source: OneexampleofthisisthattheChineseimmigrantsinIndonesiain1969
# <<C>> <<P>> <<positive>>
# target: keepingowncustomsstablymightcausediscrimination
# source: TheyformedChinatownandkeptChineselanguageandcustomsinit
# <<C>> <<P>> <<positive>>
# target: keepingowncustomsstablymightcausediscrimination
# source: WhiletheIndonesiansstoppedworkingat4:00pmandwenthomeforrest,Chineseimmigrantswerestillworking
# <<C>> <<P>> <<positive>>
# target: keepingowncustomsstablymightcausediscrimination
# source: beingmuchricherthanlocalpeople,theyfacedthediscrimination
# <<C>> <<P>> <<positive>>
# target: keepingowncustomsstablymightcausediscrimination
# source: Theirhousesandprivatecarswereburiedbylocalpeople
# <<C>> <<P>> <<positive>>
# target: Theirhousesandprivatecarswereburiedbylocalpeople
# source: thelocalswerejealousofChinesepeople,whohadsomuchwealth,whichshouldhavebeenthe
# <<P>> <<P>> <<positive>>
# target: keepingowncustomsstablymightcausediscrimination
# source: IftheChineseimmigrantshadfollowedthelocalcustomsandassimilatedintoIndonesia,theywouldnothavebeenregardsasagroupofChineseanddiscriminationmighthavebeenal
# <<C>> <<P>> <<positive>>
# ID2
# ----------prediction results----------
# (204, 225, 6, 21, 35, 7, 2)
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: Iftheydonotcooperate,therewillbelotsofdis
# <<C>> <<P>> <<positive>>
# (53, 72, 7, 39, 50, 7, 2)
# target: healwaysleftofficesharpontimewithoutgivinganyconsiderationwhethertheworkhasbeenfinishedornot
# source: Ioncehadaco-workerwhowastoofamilyconscious
# <<P>> <<P>> <<positive>>
# (204, 225, 6, 53, 72, 7, 2)
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: healwaysleftofficesharpontimewithoutgivinganyconsiderationwhethertheworkhasbeenfinishedornot
# <<C>> <<P>> <<positive>>
# (204, 225, 6, 74, 104, 7, 2)
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: Mostofthetime,Ihadtodohisworkinordertoprotecthimfromgettingcaughttothesupervisorwhowasaveryauthoritativeperson
# <<C>> <<P>> <<positive>>
# (204, 225, 6, 108, 116, 7, 2)
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: onedayIwantedtobeoffearly
# <<C>> <<P>> <<positive>>
# (108, 116, 7, 118, 126, 7, 2)
# target: onedayIwantedtobeoffearly
# source: Ihadtotakemymothertothedoctor
# <<P>> <<P>> <<positive>>
# (204, 225, 6, 128, 158, 7, 2)
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: WhenIrequestedmyco-workertogiveahelpinghandtofinishmyworkearly,heturneddownmyrequestgivingasillyexc
# <<C>> <<P>> <<positive>>
# (204, 225, 6, 166, 195, 7, 2)
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: Ididnotofferhimanysupportandfinallyhewastransferredfromourdepartmenttoadistantlocationasapunishmentforhisir
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: Iftheydonotcooperate,therewillbelotsofdis
# <<C>> <<P>> <<positive>>
# target: healwaysleftofficesharpontimewithoutgivinganyconsiderationwhethertheworkhasbeenfinishedornot
# source: Ioncehadaco-workerwhowastoofamilyconscious
# <<P>> <<P>> <<positive>>
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: healwaysleftofficesharpontimewithoutgivinganyconsiderationwhethertheworkhasbeenfinishedornot
# <<C>> <<P>> <<positive>>
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: Mostofthetime,Ihadtodohisworkinordertoprotecthimfromgettingcaughttothesupervisorwhowasaveryauthoritativeperson
# <<C>> <<P>> <<positive>>
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: onedayIwantedtobeoffearlybecauseIhadtotakemymothertothedoctor
# <<C>> <<P>> <<positive>>
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: WhenIrequestedmyco-workertogiveahelpinghandtofinishmyworkearly,heturneddownmyrequestgivingasillyexc
# <<C>> <<P>> <<positive>>
# target: iftheco-workersdonotcorporatewitheachotherthatwouldbedevastatinginaworkenvironment
# source: FromthatdayonwardsIdidnotofferhimanysupportandfinallyhewastransferredfromourdepartmenttoadistantlocationasapunishmentforhisir
# <<C>> <<P>> <<positive>>
# ID3
# ----------prediction results----------
# (196, 205, 6, 39, 80, 7, 2)
# target: technologiesarevitalinstudents'learning
# source: Computerscanbeprogrammedtoprovideanendlessnumbersofquestionsindiverserangeoffields,andasthestudentsanswerthesequestions,thefactshasbeenlearnedandre
# <<C>> <<P>> <<positive>>
# (196, 205, 6, 84, 118, 7, 2)
# target: technologiesarevitalinstudents'learning
# source: AcaseinpointisthereadingandlisteningpartsofTOEFLiBTexams,ascandidateshavetoanswermanyquestionsinalimitedperiodoftime
# <<C>> <<P>> <<positive>>
# (196, 205, 6, 122, 157, 7, 2)
# target: technologiesarevitalinstudents'learning
# source: whenstudentshavesomeacademicproblems,theycanpostthosetosomewebsitesandreceivecorrectanswersfromunknownpeopleinfarawayplaceswithoutanycost
# <<C>> <<P>> <<positive>>
# (196, 205, 6, 162, 192, 7, 2)
# target: technologiesarevitalinstudents'learning
# source: inthepast,conductingaresearchrequirelonghoursofsearchinginlibraryshelves,nowallcanbedoneataclickofabutton
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: technologiesarevitalinstudents'learning
# source: Computerscanbeprogrammedtoprovideanendlessnumbersofquestionsindiverserangeoffields,andasthestudentsanswerthesequestions,thefactshasbeenlearnedandre
# <<C>> <<P>> <<positive>>
# target: technologiesarevitalinstudents'learning
# source: AcaseinpointisthereadingandlisteningpartsofTOEFLiBTexams,ascandidateshavetoanswermanyquestionsinalimitedperiodoftime
# <<C>> <<P>> <<positive>>
# target: technologiesarevitalinstudents'learning
# source: whenstudentshavesomeacademicproblems,theycanpostthosetosomewebsitesandreceivecorrectanswersfromunknownpeopleinfarawayplaceswithoutanycost
# <<C>> <<P>> <<positive>>
# target: technologiesarevitalinstudents'learning
# source: inthepast,conductingaresearchrequirelonghoursofsearchinginlibraryshelves,nowallcanbedoneataclickofabutton
# <<C>> <<P>> <<positive>>
# ID4
# ----------prediction results----------
# (11, 21, 6, 51, 62, 7, 2)
# target: closefriendscaneasilyunderstandeachothersfeel
# source: theywouldn'tevensparetimetoconsideryourfeel
# <<C>> <<P>> <<positive>>
# (11, 21, 6, 65, 78, 7, 2)
# target: closefriendscaneasilyunderstandeachothersfeel
# source: Everyoneplaytheroleofacquaintanceandfriendatthesametime
# <<C>> <<P>> <<positive>>
# (11, 21, 6, 80, 99, 7, 2)
# target: closefriendscaneasilyunderstandeachothersfeel
# source: Beingfriendlyisagoodwaytotreataacquaintancebutwaynotenoughforafriend
# <<C>> <<P>> <<positive>>
# (194, 201, 6, 101, 135, 7, 2)
# target: afriendisapersonyoucareabout
# source: Whenmyfriendissick,Iwouldnotonlyaskifheisokaylikeanacquaintancebutdomybesttomakehimgetwellassoonasp
# <<C>> <<P>> <<positive>>
# (194, 201, 6, 138, 175, 7, 2)
# target: afriendisapersonyoucareabout
# source: Ifmyfriendisgoingtothewrongdirectioninhislifetrail,Iwilltrymybesttopullhimback,butnotstandandstarelikeit'snotofmybusiness
# <<C>> <<P>> <<positive>>
# (194, 201, 6, 181, 188, 7, 2)
# target: afriendisapersonyoucareabout
# source: myfriendwilldothesametome
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: closefriendscaneasilyunderstandeachothersfeel
# source: theywouldn'tevensparetimetoconsideryourfeel
# <<C>> <<P>> <<positive>>
# target: closefriendscaneasilyunderstandeachothersfeel
# source: Everyoneplaytheroleofacquaintanceandfriendatthesametime
# <<C>> <<P>> <<positive>>
# target: closefriendscaneasilyunderstandeachothersfeel
# source: Beingfriendlyisagoodwaytotreataacquaintancebutwaynotenoughforafriend
# <<C>> <<P>> <<positive>>
# target: afriendisapersonyoucareabout
# source: Whenmyfriendissick,Iwouldnotonlyaskifheisokaylikeanacquaintancebutdomybesttomakehimgetwellassoonasp
# <<C>> <<P>> <<positive>>
# target: afriendisapersonyoucareabout
# source: Ifmyfriendisgoingtothewrongdirectioninhislifetrail,Iwilltrymybesttopullhimback,butnotstandandstarelikeit'snotofmybusiness
# <<C>> <<P>> <<positive>>
# target: afriendisapersonyoucareabout
# source: myfriendwilldothesametome
# <<C>> <<P>> <<positive>>
# ID5
# ----------prediction results----------
# (14, 37, 6, 82, 93, 7, 2)
# target: theInternetisanadequatesourceofacademicinformation,whichwillpotentiallyfulfilltheneedsofuniversityp
# source: theInternethasgrowntobecomethelargestvirtuallibraryever
# <<C>> <<P>> <<positive>>
# (14, 37, 6, 97, 114, 7, 2)
# target: theInternetisanadequatesourceofacademicinformation,whichwillpotentiallyfulfilltheneedsofuniversityp
# source: withtheuseoftheInternet,distanceandtimeseemtobenomoreah
# <<C>> <<P>> <<positive>>
# (14, 37, 6, 118, 145, 7, 2)
# target: theInternetisanadequatesourceofacademicinformation,whichwillpotentiallyfulfilltheneedsofuniversityp
# source: Collegestudentscansavetheirtimebrowsingfornecessaryinformationthroughthewebinsteadofspendinghourswanderinginbookstoresorl
# <<C>> <<P>> <<positive>>
# (14, 37, 6, 154, 166, 7, 2)
# target: theInternetisanadequatesourceofacademicinformation,whichwillpotentiallyfulfilltheneedsofuniversityp
# source: theInternetoffersamoreeffectiveandpracticalmethodofstud
# <<C>> <<P>> <<positive>>
# (14, 37, 6, 170, 200, 7, 2)
# target: theInternetisanadequatesourceofacademicinformation,whichwillpotentiallyfulfilltheneedsofuniversityp
# source: virtualflowchartsandanimationsmaysimplifycomplicatedscientificprocesses,GoogleandWikipediaarealwaysaccessiblefordetailedresponsestoeveryquery
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: theInternetisanadequatesourceofacademicinformation,whichwillpotentiallyfulfilltheneedsofuniversityp
# source: theInternethasgrowntobecomethelargestvirtuallibraryever
# <<C>> <<P>> <<positive>>
# target: theInternetisanadequatesourceofacademicinformation,whichwillpotentiallyfulfilltheneedsofuniversityp
# source: withtheuseoftheInternet,distanceandtimeseemtobenomoreah
# <<C>> <<P>> <<positive>>
# target: withtheuseoftheInternet,distanceandtimeseemtobenomoreah
# source: Collegestudentscansavetheirtimebrowsingfornecessaryinformationthroughthewebinsteadofspendinghourswanderinginbookstoresorl
# <<P>> <<P>> <<positive>>
# target: theInternetisanadequatesourceofacademicinformation,whichwillpotentiallyfulfilltheneedsofuniversityp
# source: theInternetoffersamoreeffectiveandpracticalmethodofstud
# <<C>> <<P>> <<positive>>
# target: theInternetoffersamoreeffectiveandpracticalmethodofstud
# source: Whilevirtualflowchartsandanimationsmaysimplifycomplicatedscientificprocesses,GoogleandWikipediaarealwaysaccessiblefordetailedresponsestoeveryquery
# <<P>> <<P>> <<positive>>
# ID6
# ----------prediction results----------
# (16, 29, 6, 61, 84, 7, 2)
# target: citizenshaveotherimportantresponsibilitiestofulfilapartfrompayingtax
# source: thegovernmentcanprovidesomefundtoeasetheirdifficulties,butsuchfinancialhelpisusuallyfarfromenough
# <<C>> <<P>> <<positive>>
# (90, 113, 7, 61, 84, 7, 2)
# target: aidsfrommorecapableorwealthiercitizensareparticularlycrucial,whichareagreatcomplementtogovernmentsupport
# source: thegovernmentcanprovidesomefundtoeasetheirdifficulties,butsuchfinancialhelpisusuallyfarfromenough
# <<P>> <<P>> <<positive>>
# (16, 29, 6, 90, 113, 7, 2)
# target: citizenshaveotherimportantresponsibilitiestofulfilapartfrompayingtax
# source: aidsfrommorecapableorwealthiercitizensareparticularlycrucial,whichareagreatcomplementtogovernmentsupport
# <<C>> <<P>> <<positive>>
# (16, 29, 6, 115, 133, 7, 2)
# target: citizenshaveotherimportantresponsibilitiestofulfilapartfrompayingtax
# source: Anotherresponsibilityallcitizensshouldtakeistomaintainsocialstabilitytogetherwiththepoliceforce
# <<C>> <<P>> <<positive>>
# (159, 193, 7, 135, 156, 7, 2)
# target: itisquitenecessaryforthelocalresidentstotakeactionsandensurethesafetyofthecommunities,bydoingthingslikereportingsuspiciousactivitiestothepolicedep
# source: Therearecriminalsineverysociety,andthenumberofpolicementhegovernmentcanhireislimited
# <<P>> <<P>> <<positive>>
# (16, 29, 6, 159, 193, 7, 2)
# target: citizenshaveotherimportantresponsibilitiestofulfilapartfrompayingtax
# source: itisquitenecessaryforthelocalresidentstotakeactionsandensurethesafetyofthecommunities,bydoingthingslikereportingsuspiciousactivitiestothepolicedep
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: thereareimpoverishedordisabledpeopleineverysociety,needinghelpandsupportfromother
# source: thegovernmentcanprovidesomefundtoeasetheirdiff
# <<P>> <<P>> <<negative>>
# target: thegovernmentcanprovidesomefundtoeasetheirdiff
# source: suchfinancialhelpisusuallyfarfromenough
# <<P>> <<P>> <<negative>>
# target: citizenshaveotherimportantresponsibilitiestofulfilapartfrompayingtax
# source: aidsfrommorecapableorwealthiercitizensareparticularlycrucial,whichareagreatcomplementtogovernmentsupport
# <<C>> <<P>> <<positive>>
# target: citizenshaveotherimportantresponsibilitiestofulfilapartfrompayingtax
# source: Anotherresponsibilityallcitizensshouldtakeistomaintainsocialstabilitytogetherwiththepoliceforce
# <<C>> <<P>> <<positive>>
# target: itisquitenecessaryforthelocalresidentstotakeactionsandensurethesafetyofthecommunities,bydoingthingslikereportingsuspiciousactivitiestothepolicedep
# source: Therearecriminalsineverysociety,andthenumberofpolicementhegovernmentcanhireislimited
# <<P>> <<P>> <<positive>>
# target: citizenshaveotherimportantresponsibilitiestofulfilapartfrompayingtax
# source: itisquitenecessaryforthelocalresidentstotakeactionsandensurethesafetyofthecommunities,bydoingthingslikereportingsuspiciousactivitiestothepolicedep
# <<C>> <<P>> <<positive>>
# ID7
# ----------prediction results----------
# (9, 22, 6, 46, 75, 7, 2)
# target: Buildingmoreaccommodatingconstructionsmeetspeople'sbasicneed
# source: Ifthepriceofhousinggrowscontinuously,acomfortableplacetoliveinwillbealuxurytothemiddleclassandthelowclass
# <<C>> <<P>> <<positive>>
# (9, 22, 6, 79, 103, 7, 2)
# target: Buildingmoreaccommodatingconstructionsmeetspeople'sbasicneed
# source: ordinarypeople,especiallytheyoungergeneration,willfallintoacertainpattern-work,paybillsforhousing,work
# <<C>> <<P>> <<positive>>
# (9, 22, 6, 110, 122, 7, 2)
# target: Buildingmoreaccommodatingconstructionsmeetspeople'sbasicneed
# source: itwillincreasepeople'sdissatisfactionofthegovernment
# <<C>> <<P>> <<positive>>
# (110, 122, 7, 125, 148, 7, 2)
# target: itwillincreasepeople'sdissatisfactionofthegovernment
# source: whentheyareworking,thefairoflosingtheiraccommodationalwayslingers,whichwilllimittheirefficiency
# <<P>> <<P>> <<positive>>
# (9, 22, 6, 151, 163, 7, 2)
# target: Buildingmoreaccommodatingconstructionsmeetspeople'sbasicneed
# source: governmentshouldspendmoneyonpeopletorescuethemfromthis
# <<C>> <<P>> <<positive>>
# (151, 163, 7, 166, 192, 7, 2)
# target: governmentshouldspendmoneyonpeopletorescuethemfromthis
# source: onlyagovernmentofthepeople,bythepeople,forthepeoplewillfinallylast;people'scohesivenesswillbeprom
# <<P>> <<P>> <<positive>>
# ----------target results----------
# target: Buildingmoreaccommodatingconstructionsmeetspeople'sbasicneed
# source: Ifthepriceofhousinggrowscontinuously,acomfortableplacetoliveinwillbealuxurytothemiddleclassandthelowclass
# <<C>> <<P>> <<positive>>
# target: Buildingmoreaccommodatingconstructionsmeetspeople'sbasicneed
# source: ordinarypeople,especiallytheyoungergeneration,willfallintoacertainpattern-work,paybillsforhousing,work;andIamsurethatitwillincreasepeople'sdissatisfactionofthegovernment
# <<C>> <<P>> <<positive>>
# target: Buildingmoreaccommodatingconstructionsmeetspeople'sbasicneed
# source: whentheyareworking,thefairoflosingtheiraccommodationalwayslingers,whichwilllimittheirefficiency
# <<C>> <<P>> <<positive>>
# target: Buildingmoreaccommodatingconstructionsmeetspeople'sbasicneed
# source: governmentshouldspendmoneyonpeopletorescuethemfromthis
# <<C>> <<P>> <<positive>>
# target: governmentshouldspendmoneyonpeopletorescuethemfromthis
# source: onlyagovernmentofthepeople,bythepeople,forthepeoplewillfinallylast;people'scohesivenesswillbeprom
# <<P>> <<P>> <<positive>>
# ID8
# ----------prediction results----------
# (28, 54, 6, 80, 106, 7, 2)
# target: Byattendingtothesameschool,studentscanlearnhowtoviewtheoppositegenderinclassesasafriendoraclass
# source: Theywouldknowhowtoaskherinordertocooperatewithhisstudy,howcommunicatewithgirlsinagroup,etc
# <<C>> <<P>> <<positive>>
# (28, 54, 6, 111, 129, 7, 2)
# target: Byattendingtothesameschool,studentscanlearnhowtoviewtheoppositegenderinclassesasafriendoraclass
# source: whentheystudytogetherandhelpeachother,theyexercisethethereallifeastheyage
# <<C>> <<P>> <<positive>>
# (183, 190, 7, 135, 157, 7, 2)
# target: theirthoughtsdeviatefromthestud
# source: someexpertsbelievethatattendingbothgirlsandboysinasameschoolcausemanydisadvantagesforthem
# <<P>> <<P>> <<positive>>
# (183, 190, 7, 163, 177, 7, 2)
# target: theirthoughtsdeviatefromthestud
# source: outdoorsrelationshipsmayexpandanditmayaccompanywithsexualrelations
# <<P>> <<P>> <<positive>>
# ----------target results----------
# target: Byattendingtothesameschool,studentscanlearnhowtoviewtheoppositegenderinclassesasafriendoraclass
# source: aboywouldknowhowtospeakwithagirlineverysituationandvicevers
# <<C>> <<P>> <<positive>>
# target: Byattendingtothesameschool,studentscanlearnhowtoviewtheoppositegenderinclassesasafriendoraclass
# source: Theywouldknowhowtoaskherinordertocooperatewithhisstudy,howcommunicatewithgirlsinagroup,etc
# <<C>> <<P>> <<positive>>
# target: Byattendingtothesameschool,studentscanlearnhowtoviewtheoppositegenderinclassesasafriendoraclass
# source: whentheystudytogetherandhelpeachother,theyexercisethethereallifeastheyage
# <<C>> <<P>> <<positive>>
# target: Byattendingtothesameschool,studentscanlearnhowtoviewtheoppositegenderinclassesasafriendoraclass
# source: attendingbothgirlsandboysinasameschoolcausemanydisadvantagesforthem
# <<C>> <<P>> <<negative>>
# target: theirthoughtsdeviatefromthestud
# source: outdoorsrelationshipsmayexpandanditmayaccompanywithsexualrelations
# <<P>> <<P>> <<positive>>
# target: attendingbothgirlsandboysinasameschoolcausemanydisadvantagesforthem
# source: theirthoughtsdeviatefromthestud
# <<P>> <<P>> <<positive>>
# ID9
# ----------prediction results----------
# (61, 67, 7, 69, 78, 7, 2)
# target: apersonalcarusesisinneed
# source: apublictransportationcan'tmeeteveryplace
# <<P>> <<P>> <<positive>>
# (61, 67, 7, 83, 103, 7, 3)
# target: apersonalcarusesisinneed
# source: itmaybetruewhenyouwanttogotosomecountrysideorsomeotherinconvenienceplaces
# <<P>> <<P>> <<negative>>
# (61, 67, 7, 107, 156, 7, 3)
# target: apersonalcarusesisinneed
# source: nomatteryouaregoingtosomewhereforatriporyoujustsimplyliveinsomesuburbsandsoon,italwayshavesomeotherwaysthatyoucando,youcanrideabike,orevenwalkonyourfeet
# <<P>> <<P>> <<negative>>
# (61, 67, 7, 158, 175, 7, 3)
# target: apersonalcarusesisinneed
# source: Itnotonlyhelpsyoutoreducethecaruse,butalsogoodtoyourhealth
# <<P>> <<P>> <<negative>>
# (61, 67, 7, 181, 189, 7, 3)
# target: apersonalcarusesisinneed
# source: thiswon'tbeaproblematall
# <<P>> <<P>> <<negative>>
# ----------target results----------
# target: apersonalcarusesisinneed
# source: itmaybetruewhenyouwanttogotosomecountrysideorsomeotherinconvenienceplaces
# <<C>> <<P>> <<positive>>
# target: apersonalcarusesisinneed
# source: nomatteryouaregoingtosomewhereforatriporyoujustsimplyliveinsomesuburbsandsoon,italwayshavesomeotherwaysthatyoucando,youcanrideabike,orevenwalkonyourfeet
# <<C>> <<P>> <<positive>>
# target: nomatteryouaregoingtosomewhereforatriporyoujustsimplyliveinsomesuburbsandsoon,italwayshavesomeotherwaysthatyoucando,youcanrideabike,orevenwalkonyourfeet
# source: Itnotonlyhelpsyoutoreducethecaruse,butalsogoodtoyourhealth
# <<P>> <<P>> <<positive>>
# target: apublictransportationcan'tmeeteveryplace
# source: thiswon'tbeaproblematall
# <<P>> <<P>> <<negative>>
# ID10
# ----------prediction results----------
# (13, 24, 6, 51, 77, 7, 2)
# target: advertisingisnotentirelydecisiveonpersonaleatinghab
# source: Itissurethatadvertisingalwaysmakestheproductssotempting,regardlessofwhethertheymightbringnegativeeffectsonthehumanbody
# <<C>> <<P>> <<positive>>
# (13, 24, 6, 81, 89, 7, 2)
# target: advertisingisnotentirelydecisiveonpersonaleatinghab
# source: advertisingisnottheonlyinformationsourceforpeople
# <<C>> <<P>> <<positive>>
# (13, 89, 7, 91, 110, 7, 2)
# target: advertisingisnotentirelydecisiveonpersonaleatinghabit.Thekeytoformingahealthyeatingpatternliesinpeople'sconceptofwholesomedietsandself-control.Itissurethatadvertisingalwaysmakestheproductssotempting,regardlessofwhethertheymightbringnegativeeffectsonthehumanbody.However,advertisingisnottheonlyinformationsourceforpeople
# source: Peoplecanstillacquiredifferentviewpointsaboutfoodsfromothersources,likenewsormag
# <<P>> <<P>> <<positive>>
# (13, 89, 6, 113, 149, 7, 2)
# target: advertisingisnotentirelydecisiveonpersonaleatinghabit.Thekeytoformingahealthyeatingpatternliesinpeople'sconceptofwholesomedietsandself-control.Itissurethatadvertisingalwaysmakestheproductssotempting,regardlessofwhethertheymightbringnegativeeffectsonthehumanbody.However,advertisingisnottheonlyinformationsourceforpeople
# source: Aslongaspeopleareclearabouthowtomaintainahealthybodyandtheypersistentlykeeptrackoftheireatinghabits,theycansuccessfullypreventthemselvesfromthoset
# <<C>> <<P>> <<positive>>
# (13, 24, 6, 153, 186, 7, 2)
# target: advertisingisnotentirelydecisiveonpersonaleatinghab
# source: Itwillbenotpersuasiveifpeoplejustblametheadvertisingsectorofafast-foodcompanyformakingthemsofatandnotreassesstheirownbeh
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: advertisingisnotentirelydecisiveonpersonaleatinghab
# source: advertisingalwaysmakestheproductssotempting,regardlessofwhethertheymightbringnegativeeffectsonthehumanbody
# <<C>> <<P>> <<negative>>
# target: advertisingalwaysmakestheproductssotempting,regardlessofwhethertheymightbringnegativeeffectsonthehumanbody
# source: advertisingisnottheonlyinformationsourceforpeople
# <<P>> <<P>> <<positive>>
# target: advertisingisnottheonlyinformationsourceforpeople
# source: Peoplecanstillacquiredifferentviewpointsaboutfoodsfromothersources,likenewsormag
# <<P>> <<P>> <<positive>>
# target: advertisingisnotentirelydecisiveonpersonaleatinghab
# source: Aslongaspeopleareclearabouthowtomaintainahealthybodyandtheypersistentlykeeptrackoftheireatinghabits,theycansuccessfullypreventthemselvesfromthoset
# <<C>> <<P>> <<positive>>
# target: advertisingisnotentirelydecisiveonpersonaleatinghab
# source: Itwillbenotpersuasiveifpeoplejustblametheadvertisingsectorofafast-foodcompanyformakingthemsofatandnotreassesstheirownbeh
# <<C>> <<P>> <<positive>>
# ID11
# ----------prediction results----------
# (11, 20, 6, 45, 70, 7, 2)
# target: thestudyingconditionsarebetterinanap
# source: Alotofstudentsoftencomplainabouttheirroommateplayingmusictooloudorbringingfriendsoveratinappropriatetimes
# <<C>> <<P>> <<positive>>
# (99, 107, 7, 73, 93, 7, 2)
# target: youwouldbeabletoconcentratebetter
# source: inanapartmentyoudon'thavearoommate,youwon'thavethisproblem
# <<P>> <<P>> <<positive>>
# (11, 20, 6, 99, 107, 7, 2)
# target: thestudyingconditionsarebetterinanap
# source: youwouldbeabletoconcentratebetter
# <<C>> <<P>> <<positive>>
# (11, 20, 6, 114, 141, 7, 2)
# target: thestudyingconditionsarebetterinanap
# source: youwon'thaveaproblemifyouaretheonewhowantstoplaymusic,bringfriendsover,orstudylateatnight
# <<C>> <<P>> <<positive>>
# (11, 20, 6, 143, 147, 7, 2)
# target: thestudyingconditionsarebetterinanap
# source: Yousetyourownsc
# <<C>> <<P>> <<positive>>
# (11, 20, 6, 156, 188, 7, 2)
# target: thestudyingconditionsarebetterinanap
# source: livinginadormitory,andbeingsurroundedbystudentsalsohassomeadvantages,likebeingabletogethelpwithanyacademicissuesfromthem
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: thestudyingconditionsarebetterinanap
# source: Alotofstudentsoftencomplainabouttheirroommateplayingmusictooloudorbringingfriendsoveratinappropriatetimes
# <<C>> <<P>> <<positive>>
# target: youwon'thavethisproblem
# source: inanapartmentyoudon'thavearo
# <<P>> <<P>> <<positive>>
# target: youwouldbeabletoconcentratebetter
# source: youwon'thavethisproblem
# <<P>> <<P>> <<positive>>
# target: thestudyingconditionsarebetterinanap
# source: youwouldbeabletoconcentratebetter
# <<C>> <<P>> <<positive>>
# target: thestudyingconditionsarebetterinanap
# source: youwon'thaveaproblemifyouaretheonewhowantstoplaymusic,bringfriendsover,orstudylateatnight
# <<C>> <<P>> <<positive>>
# target: thestudyingconditionsarebetterinanap
# source: Yousetyourownsc
# <<C>> <<P>> <<positive>>
# target: thestudyingconditionsarebetterinanap
# source: livinginadormitory,andbeingsurroundedbystudentsalsohassomeadvantages,likebeingabletogethelpwithanyacademicissuesfromthem
# <<C>> <<P>> <<negative>>
# ID12
# ----------prediction results----------
# (9, 36, 6, 71, 92, 7, 2)
# target: Traditionalskillsandlifestylesplayimportantroleinmodernsociety,intermsofhealthcare,environmentalprotectionandculturalinher
# source: traditionalwaysoflifeisagreatcomplimentaryformodernlifeandhighlighttheimportanceofworklifebalance
# <<C>> <<P>> <<positive>>
# (9, 36, 6, 101, 132, 7, 2)
# target: Traditionalskillsandlifestylesplayimportantroleinmodernsociety,intermsofhealthcare,environmentalprotectionandculturalinher
# source: traditionalskillsrelylittleonfossilenergy,itismoreenvironmentally-friendly,whichshouldbepromotedtoreducethethreatofclimatechange
# <<C>> <<P>> <<positive>>
# (9, 36, 6, 135, 147, 7, 2)
# target: Traditionalskillsandlifestylesplayimportantroleinmodernsociety,intermsofhealthcare,environmentalprotectionandculturalinher
# source: thosetradition-relatedthingsconveytraditionalcultureandvalues
# <<C>> <<P>> <<positive>>
# (135, 155, 7, 158, 184, 7, 2)
# target: thosetradition-relatedthingsconveytraditionalcultureandvalues.Theseareimportantfoundationofmoderncivil
# source: Protectionoftraditioncanprovidethepossibilitytobetterunderstandancientcultureandutilizethemtotacklemodernpro
# <<P>> <<P>> <<positive>>
# ----------target results----------
# target: technologytakesconveniencetohum
# source: italsocontributestounhealthybehaviorsoflife,likesedentaryl
# <<P>> <<P>> <<negative>>
# target: Traditionalskillsandlifestylesplayimportantroleinmodernsociety,intermsofhealthcare,environmentalprotectionandculturalin
# source: traditionalwaysoflifeisagreatcomplimentaryformodernlifeandhighlighttheimportanceofworklifebalance
# <<C>> <<P>> <<positive>>
# target: itismoreenvironmentally-friendly,whichshouldbepromotedtoreducethethreatofclimatechange
# source: traditionalskillsrelylittleonfossilenergy
# <<P>> <<P>> <<positive>>
# target: Traditionalskillsandlifestylesplayimportantroleinmodernsociety,intermsofhealthcare,environmentalprotectionandculturalin
# source: itismoreenvironmentally-friendly,whichshouldbepromotedtoreducethethreatofclimatechange
# <<C>> <<P>> <<positive>>
# target: Traditionalskillsandlifestylesplayimportantroleinmodernsociety,intermsofhealthcare,environmentalprotectionandculturalin
# source: thosetradition-relatedthingsconveytraditionalcultureandvalues
# <<C>> <<P>> <<positive>>
# target: thosetradition-relatedthingsconveytraditionalcultureandvalues
# source: Theseareimportantfoundationofmoderncivil
# <<P>> <<P>> <<positive>>
# target: Traditionalskillsandlifestylesplayimportantroleinmodernsociety,intermsofhealthcare,environmentalprotectionandculturalin
# source: Protectionoftraditioncanprovidethepossibilitytobetterunderstandancientcultureandutilizethemtotacklemodernpro
# <<C>> <<P>> <<positive>>
# ID13
# ----------prediction results----------
# (24, 45, 6, 74, 82, 7, 2)
# target: theeducationalbenefitsthattheInternetmayyieldareundeniable,therestillremaincertainshort
# source: informationfromthosesourcesissubjecttoquestion
# <<C>> <<P>> <<positive>>
# (74, 82, 7, 87, 121, 7, 3)
# target: informationfromthosesourcesissubjecttoquestion
# source: thecomputercanshowwhetherananswertoaparticularquestionisrightorwrongbutitcannotgiveasanin-depthexplanationasahumanteachercan
# <<P>> <<P>> <<negative>>
# (147, 169, 7, 123, 142, 7, 2)
# target: adjustingandtailoringhisorherteachingmethodologytomeetthelevelsorthedemandsofthosestud
# source: Throughface-to-facecommunication,teacherscanalsopinpointtheweaknessesofeachstudent
# <<P>> <<P>> <<positive>>
# (24, 45, 7, 147, 169, 7, 2)
# target: theeducationalbenefitsthattheInternetmayyieldareundeniable,therestillremaincertainshort
# source: adjustingandtailoringhisorherteachingmethodologytomeetthelevelsorthedemandsofthosestud
# <<P>> <<P>> <<positive>>
# (24, 45, 7, 172, 181, 7, 2)
# target: theeducationalbenefitsthattheInternetmayyieldareundeniable,therestillremaincertainshort
# source: Thisiswherethecomputerprovestobein
# <<P>> <<P>> <<positive>>
# ----------target results----------
# target: itcannotgiveasanin-depthexplanationasahumanteachercan
# source: thecomputercanshowwhetherananswertoaparticularquestionisrightorwrong
# <<C>> <<P>> <<negative>>
# target: itcannotgiveasanin-depthexplanationasahumanteachercan
# source: Throughface-to-facecommunication,teacherscanalsopinpointtheweaknessesofeachstudentandtherefore,adjustingandtailoringhisorherteachingmethodologytomeetthelevelsorthedemandsofthosestud
# <<C>> <<P>> <<positive>>
# target: itcannotgiveasanin-depthexplanationasahumanteachercan
# source: Thisiswherethecomputerprovestobein
# <<C>> <<P>> <<positive>>
# ID14
# ----------prediction results----------
# (9, 26, 6, 95, 109, 7, 2)
# target: Therearealotofadvancesgoingontechnologywhicharehelpingtheenvironmentalot
# source: Japanisworkingtobuildaworkingspacesolarpowersystemby2030
# <<C>> <<P>> <<positive>>
# (9, 26, 6, 111, 142, 7, 2)
# target: Therearealotofadvancesgoingontechnologywhicharehelpingtheenvironmentalot
# source: Bydrawingonthecolossalenergyofthesun,itcouldmeettheentireworld'selectricityrequirementsindefinitelywithoutnuclearorGHG
# <<C>> <<P>> <<positive>>
# (9, 26, 6, 149, 156, 7, 2)
# target: Therearealotofadvancesgoingontechnologywhicharehelpingtheenvironmentalot
# source: theimpactontheworldwouldbemon
# <<C>> <<P>> <<positive>>
# (149, 156, 7, 160, 173, 7, 2)
# target: theimpactontheworldwouldbemon
# source: Itwouldmeanenergyforschools,hospitals,andh
# <<P>> <<P>> <<positive>>
# (9, 26, 6, 176, 181, 7, 2)
# target: Therearealotofadvancesgoingontechnologywhicharehelpingtheenvironmentalot
# source: Itwouldmeananotherindustrialrevolution
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: OneprimeexampleisfindingsolutionstowaterproblemsindevelopingcountriessuchasAf
# source: Bypressurisingseawatertoproducevapourjetsandfilteringthemthroughcarbonnanotubes,wecangetcleandrinkingwaterfromseawater-analmostinexhaustibleresource
# <<P>> <<P>> <<positive>>
# target: Therearealotofadvancesgoingontechnologywhicharehelpingtheenvironmentalot
# source: Japanisworkingtobuildaworkingspacesolarpowersystemby20
# <<C>> <<P>> <<positive>>
# target: Therearealotofadvancesgoingontechnologywhicharehelpingtheenvironmentalot
# source: Bydrawingonthecolossalenergyofthesun,itcouldmeettheentireworld'selectricityrequirementsindefinitelywithoutnuclearorGHGem
# <<C>> <<P>> <<positive>>
# target: Therearealotofadvancesgoingontechnologywhicharehelpingtheenvironmentalot
# source: Ifsuccessful,theimpactontheworldwouldbemon
# <<C>> <<P>> <<positive>>
# target: Ifsuccessful,theimpactontheworldwouldbemon
# source: Itwouldmeanenergyforschools,hospitals,andh
# <<P>> <<P>> <<positive>>
# target: Ifsuccessful,theimpactontheworldwouldbemon
# source: Itwouldmeananotherindustrialrevolution
# <<P>> <<P>> <<positive>>
# ID15
# ----------prediction results----------
# (170, 178, 6, 39, 55, 7, 2)
# target: almostofusliveintheenvironmentofgroups
# source: thegroupsplayanessentialroleintheprocessofsocialization,fromchildrentoad
# <<C>> <<P>> <<positive>>
# (170, 178, 6, 58, 86, 7, 2)
# target: almostofusliveintheenvironmentofgroups
# source: Webegintakingpartingroupsororganizationsduringtheearlydaysoflife,andespeciallymostpeoplecontinuetheirsocialparticipationinallthroughlife
# <<C>> <<P>> <<positive>>
# (170, 178, 6, 88, 106, 7, 2)
# target: almostofusliveintheenvironmentofgroups
# source: Bymakingteamwork,thechildreninschoolsmaylearntohowtogetalongwithother
# <<C>> <<P>> <<positive>>
# (170, 178, 6, 109, 140, 7, 2)
# target: almostofusliveintheenvironmentofgroups
# source: Asuniversitystudents,itislikelyforthemtojoinstudentorganizationoftheirmajorinordertoexpandtheirexperiencesorcommunicatewithother
# <<C>> <<P>> <<positive>>
# (170, 178, 6, 143, 165, 7, 2)
# target: almostofusliveintheenvironmentofgroups
# source: Aftergraduatingfromschools,employeesmightgotobusinessassociationsforvariousbusinessresourcesandbenef
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: almostofusliveintheenvironmentofgroups
# source: Webegintakingpartingroupsororganizationsduringtheearlydaysoflife,andespeciallymostpeoplecontinuetheirsocialparticipationinallthroughlife
# <<C>> <<P>> <<positive>>
# target: almostofusliveintheenvironmentofgroups
# source: Bymakingteamwork,thechildreninschoolsmaylearntohowtogetalongwithother
# <<C>> <<P>> <<positive>>
# target: almostofusliveintheenvironmentofgroups
# source: Asuniversitystudents,itislikelyforthemtojoinstudentorganizationoftheirmajorinordertoexpandtheirexperiencesorcommunicatewithother
# <<C>> <<P>> <<positive>>
# target: almostofusliveintheenvironmentofgroups
# source: Aftergraduatingfromschools,employeesmightgotobusinessassociationsforvariousbusinessresourcesandbenef
# <<C>> <<P>> <<positive>>
# ID16
# ----------prediction results----------
# (9, 18, 6, 31, 43, 7, 2)
# target: Historicbuildingshaveintrinsicvalues
# source: Oldbuildingsareremindersofacity'scultureandcomplex
# <<C>> <<P>> <<positive>>
# (9, 18, 6, 46, 79, 7, 2)
# target: Historicbuildingshaveintrinsicvalues
# source: Byseeinghistoricbuildings--whetherrelatedtosomethingfamousorrecognizablydramatic,peopleareabletowitnesstheaestheticandculturalhistoryofanarea
# <<C>> <<P>> <<positive>>
# (46, 79, 7, 84, 111, 7, 2)
# target: Byseeinghistoricbuildings--whetherrelatedtosomethingfamousorrecognizablydramatic,peopleareabletowitnesstheaestheticandculturalhistoryofanarea
# source: whensomebodymentionsBeijing,China'scapitalcity,youwillimmediatelyhaveCapitalPalacecometoappearinyourmind
# <<P>> <<P>> <<positive>>
# (84, 111, 7, 114, 142, 7, 2)
# target: whensomebodymentionsBeijing,China'scapitalcity,youwillimmediatelyhaveCapitalPalacecometoappearinyourmind
# source: itisthemostremarkablesignofthecity,andalsoitistheinevitablehistoryofBeijing,eventheentireChina
# <<P>> <<P>> <<positive>>
# (9, 18, 6, 144, 170, 7, 2)
# target: Historicbuildingshaveintrinsicvalues
# source: DependingonthestudyofCapitalPalace,researchershaveacomprehensiveunderstandingofthehistoryandtheculture
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: Historicbuildingshaveintrinsicvalues
# source: Oldbuildingsareremindersofacity'scultureandcomplex
# <<C>> <<P>> <<positive>>
# target: Historicbuildingshaveintrinsicvalues
# source: Byseeinghistoricbuildings--whetherrelatedtosomethingfamousorrecognizablydramatic,peopleareabletowitnesstheaestheticandculturalhistoryofanarea
# <<C>> <<P>> <<positive>>
# target: Historicbuildingshaveintrinsicvalues
# source: whensomebodymentionsBeijing,China'scapitalcity,youwillimmediatelyhaveCapitalPalacecometoappearinyourmind
# <<C>> <<P>> <<positive>>
# target: whensomebodymentionsBeijing,China'scapitalcity,youwillimmediatelyhaveCapitalPalacecometoappearinyourmind
# source: itisthemostremarkablesignofthecity,andalsoitistheinevitablehistoryofBeijing,eventheentireChina
# <<P>> <<P>> <<positive>>
# target: whensomebodymentionsBeijing,China'scapitalcity,youwillimmediatelyhaveCapitalPalacecometoappearinyourmind
# source: DependingonthestudyofCapitalPalace,researchershaveacomprehensiveunderstandingofthehistoryandtheculture
# <<P>> <<P>> <<positive>>
# ID17
# ----------prediction results----------
# (18, 23, 6, 73, 82, 7, 2)
# target: Computershavemadehumansover
# source: Computersexposechildrentovulgarmaterial
# <<C>> <<P>> <<positive>>
# (18, 23, 6, 85, 116, 7, 2)
# target: Computershavemadehumansover
# source: Theyhaveeveninvadedmentalhealthofhumans,forexample,FAD(FacebookAddictionDisorder-excessiveuseofsocialnetworkingwebsiteFacebook
# <<C>> <<P>> <<positive>>
# (18, 23, 6, 119, 145, 7, 2)
# target: Computershavemadehumansover
# source: Computershaveintrudedourlivestotheeffectthatasatellitecanpeepintoourhomesandprivatesl
# <<C>> <<P>> <<positive>>
# (18, 23, 6, 148, 168, 7, 2)
# target: Computershavemadehumansover
# source: TherecentcaseofWikileaks,leakingconfidentialdataisanexampleofhowcomputersareharm
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: Computershavemadehumansover
# source: Computersexposechildrentovulgarmaterial
# <<C>> <<P>> <<positive>>
# target: Computershavemadehumansover
# source: Theyhaveeveninvadedmentalhealthofhumans,forexample,FAD(FacebookAddictionDisorder-excessiveuseofsocialnetworkingwebsiteFacebook)
# <<C>> <<P>> <<positive>>
# target: Computershavemadehumansover
# source: Computershaveintrudedourlivestotheeffectthatasatellitecanpeepintoourhomesandprivatesl
# <<C>> <<P>> <<positive>>
# target: Computershavemadehumansover
# source: TherecentcaseofWikileaks,leakingconfidentialdataisanexampleofhowcomputersareharm
# <<C>> <<P>> <<positive>>
# ID18
# ----------prediction results----------
# (155, 168, 6, 37, 63, 7, 2)
# target: peopleunderstandtheculture,andthentheyadapttothenewcountry
# source: Whenpeoplemigratetoanewcountry,theyarelikelytosufferthecultureshock,becauseofthedifferencebetweentwocult
# <<C>> <<P>> <<positive>>
# (155, 168, 6, 66, 89, 7, 2)
# target: peopleunderstandtheculture,andthentheyadapttothenewcountry
# source: Thecustomisjustaformofthecultureandfollowingthecustomisagoodwaytoknowmoreaboutthisculture
# <<C>> <<P>> <<positive>>
# (155, 168, 6, 94, 149, 7, 2)
# target: peopleunderstandtheculture,andthentheyadapttothenewcountry
# source: ifoneworeinwhiteandwenttocommonViharastoobservearatherlonger-than-usual,full-lengthBuddhistsutrainBuddha'sBirthdayinIndia,heorshewouldlearnsomethingaboutIndianreligionandculture
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: itwillbeeasierforpeopletoassimilateintoanewcountry,iftheyfollowthenewcustom
# source: Thecustomisjustaformofthecultureandfollowingthecustomisagoodwaytoknowmoreaboutthisculture
# <<C>> <<P>> <<positive>>
# target: peopleunderstandtheculture,andthentheyadapttothenewcountry
# source: ifoneworeinwhiteandwenttocommonViharastoobservearatherlonger-than-usual,full-lengthBuddhistsutrainBuddha'sBirthdayinIndia,heorshewouldlearnsomethingaboutIndianreligionandculture
# <<P>> <<P>> <<positive>>
# target: itwillbeeasierforpeopletoassimilateintoanewcountry,iftheyfollowthenewcustom
# source: peopleunderstandtheculture,andthentheyadapttothenewcountry
# <<C>> <<P>> <<positive>>
# ID19
# ----------prediction results----------
# (11, 22, 6, 48, 63, 7, 2)
# target: inchildhoodmostpeoplearehappierthaninad
# source: Theyjustworryabouttwothings:tohavefun,learnandbehappy
# <<C>> <<P>> <<positive>>
# (11, 22, 6, 65, 75, 7, 2)
# target: inchildhoodmostpeoplearehappierthaninad
# source: Achild'sdailylifeisschool,playingandsle
# <<C>> <<P>> <<positive>>
# (11, 22, 6, 81, 114, 7, 2)
# target: inchildhoodmostpeoplearehappierthaninad
# source: whenIwasyoungIjustcamehomefromschoolandthenIwouldtookmybikeorsoccerballandgooutandplaywithmyfriendsinmyne
# <<C>> <<P>> <<positive>>
# (11, 22, 6, 121, 140, 7, 2)
# target: inchildhoodmostpeoplearehappierthaninad
# source: Ididnothavetoworryaboutcostsandotherthings,Ijusthadfunandlearn
# <<C>> <<P>> <<positive>>
# (11, 22, 6, 145, 168, 7, 2)
# target: inchildhoodmostpeoplearehappierthaninad
# source: peoplearemostcreativewhentheywerechildren,childrenimaginenewthingsandgamesjusttohavefunandbehappy
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: inchildhoodmostpeoplearehappierthaninad
# source: Theyjustworryabouttwothings:tohavefun,learnandbehappy
# <<C>> <<P>> <<positive>>
# target: Theydonothavetoworryaboutbills,jobs,howwouldtheirlifebeinthefuture
# source: Achild'sdailylifeisschool,playingandsle
# <<P>> <<P>> <<positive>>
# target: inchildhoodmostpeoplearehappierthaninad
# source: whenIwasyoungIjustcamehomefromschoolandthenIwouldtookmybikeorsoccerballandgooutandplaywithmyfriendsinmyne
# <<C>> <<P>> <<positive>>
# target: inchildhoodmostpeoplearehappierthaninad
# source: Ididnothavetoworryaboutcostsandotherthings,Ijusthadfunandlearn
# <<C>> <<P>> <<positive>>
# target: peoplearemostcreativewhentheywerechildren
# source: childrenimaginenewthingsandgamesjusttohavefunandbehappy
# <<C>> <<P>> <<positive>>
# ID20
# ----------prediction results----------
# (13, 26, 6, 63, 82, 7, 2)
# target: boysandgirlshavethediversityinpsychologicalmodesandindividual
# source: therearemoremalescientistsandengineersincomparisonwithfemalesaroundtheworld
# <<C>> <<P>> <<positive>>
# (13, 26, 6, 84, 106, 7, 2)
# target: boysandgirlshavethediversityinpsychologicalmodesandindividual
# source: Manyboysareinterestedinscienceandtechnology,whileanumberofgirlsliketolearnliterature,educationandarts
# <<C>> <<P>> <<positive>>
# (13, 26, 6, 110, 134, 7, 2)
# target: boysandgirlshavethediversityinpsychologicalmodesandindividual
# source: girlsaremorelikelytoprefersomejobsrelatedtoemotionandcommunication,suchasteacher,singerandinter
# <<C>> <<P>> <<positive>>
# (110, 134, 7, 142, 167, 7, 2)
# target: girlsaremorelikelytoprefersomejobsrelatedtoemotionandcommunication,suchasteacher,singerandinter
# source: girlsdifferfromboysinmindandbehaviourtoalargeextent,andtheybothhavebetterabilityinthespecificas
# <<P>> <<P>> <<positive>>
# ----------target results----------
# target: boysandgirlshavethediversityinpsychologicalmodesandindividual
# source: therearemoremalescientistsandengineersincomparisonwithfemalesaroundtheworld
# <<C>> <<P>> <<positive>>
# target: boysandgirlshavethediversityinpsychologicalmodesandindividual
# source: Manyboysareinterestedinscienceandtechnology,whileanumberofgirlsliketolearnliterature,educationandarts
# <<C>> <<P>> <<positive>>
# target: boysandgirlshavethediversityinpsychologicalmodesandindividual
# source: girlsaremorelikelytoprefersomejobsrelatedtoemotionandcommunication,suchasteacher,singerandinter
# <<C>> <<P>> <<positive>>
# target: boysandgirlshavethediversityinpsychologicalmodesandindividual
# source: girlsdifferfromboysinmindandbehaviourtoalargeextent,andtheybothhavebetterabilityinthespecificas
# <<C>> <<P>> <<positive>>
# ID21
# ----------prediction results----------
# (14, 54, 6, 94, 123, 7, 2)
# target: sportseventsaregoodchancesforexcellentathletestomeetandlearnvaluableexperiencesfromoneanothersothattheycanimprovetheirresults,breakrecordsandbringvictoriestotheirowncount
# source: sporteventswiththespiritofhealthiness,honestyandfairnesscanhelpstrengthenunderstanding,friendshipandsolidarityamongn
# <<C>> <<P>> <<positive>>
# (94, 123, 7, 126, 166, 7, 2)
# target: sporteventswiththespiritofhealthiness,honestyandfairnesscanhelpstrengthenunderstanding,friendshipandsolidarityamongn
# source: Aftersharingcompetitivebutinterestingmomentsineachcompetition,thecompetitorsoftenshakehandsfriendlyandcongratulatethewinners,whichcanleadtoanimprovementintherelationshipsamongn
# <<P>> <<P>> <<positive>>
# ----------target results----------
# target: therearemanygoodopportunitiesfordiscoveringdifferentcult
# source: alargenumberofpeoplewillgatherinthehostcityforsportevents
# <<P>> <<P>> <<positive>>
# target: sporteventswiththespiritofhealthiness,honestyandfairnesscanhelpstrengthenunderstanding,friendshipandsolidarityamongn
# source: therearemanygoodopportunitiesfordiscoveringdifferentcult
# <<C>> <<P>> <<positive>>
# target: sporteventswiththespiritofhealthiness,honestyandfairnesscanhelpstrengthenunderstanding,friendshipandsolidarityamongn
# ...
# source: itisadvantagewhichincreaseanopportunityonmyresumeforthesakeofgettingabetterjob
# <<P>> <<P>> <<positive>>
# ID52
# ----------prediction results----------
# (38, 57, 7, 62, 84, 7, 2)
# target: asingleinternationallanguagemay,tosomeextent,erodetheculturalidentityofanation
# source: peoplemaybeimpressedbytheculturalvaluesbroughtwiththeuniversallanguage,erodingasenseofnationalbel
# <<P>> <<P>> <<positive>>
# (15, 30, 6, 90, 105, 7, 2)
# target: thedisadvantagesofthepromotionofauniversallanguagecannotbeden
# source: someAsiansareseekingindividualism,previouslydeniedbymanyAsiancount
# <<C>> <<P>> <<positive>>
# (90, 105, 7, 113, 145, 7, 2)
# target: someAsiansareseekingindividualism,previouslydeniedbymanyAsiancount
# source: theyhavegraduallyidentifiedwithsuchvaluesexpressedinAmericanmovies,whichareimportedbythegovernmentsasaresultoftheproliferationofEnglish
# <<P>> <<P>> <<positive>>
# ----------target results----------
# target: peoplemaybeimpressedbytheculturalvaluesbroughtwiththeuniversallanguage,erodingasenseofnationalbel
# source: someAsiansareseekingindividualism,previouslydeniedbymanyAsiancount
# <<P>> <<P>> <<positive>>
# target: someAsiansareseekingindividualism,previouslydeniedbymanyAsiancount
# source: theyhavegraduallyidentifiedwithsuchvaluesexpressedinAmericanmovies,whichareimportedbythegovernmentsasaresultoftheproliferationofEnglish
# <<P>> <<P>> <<positive>>
# ID53
# ----------prediction results----------
# (129, 144, 6, 35, 58, 7, 2)
# target: studyinghardinschoolisanimportantfactortosucceedinajob
# source: Inschool,weareabletoidentifyskillsrequiredforourfuturejobandworkonmasteringandlearningthem
# <<C>> <<P>> <<positive>>
# (129, 144, 6, 60, 81, 7, 2)
# target: studyinghardinschoolisanimportantfactortosucceedinajob
# source: Ifwestudythemhard,wewillhavethechanceofdoingourjobbetterandquickerinthefuture
# <<C>> <<P>> <<positive>>
# (129, 144, 6, 86, 122, 7, 2)
# target: studyinghardinschoolisanimportantfactortosucceedinajob
# source: ifsomeonewantstobecomeagoodindustrialengineer,heshouldstudyhistechnicalcoursesverywellsothathewillbeabletoutilizethemwellinhisfuturejob
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: studyinghardinschoolisanimportantfactortosucceedinajob
# source: Thiscanbedoneinschool
# <<C>> <<P>> <<positive>>
# target: studyinghardinschoolisanimportantfactortosucceedinajob
# source: Inschool,weareabletoidentifyskillsrequiredforourfuturejobandworkonmasteringandlearningthem
# <<C>> <<P>> <<positive>>
# target: studyinghardinschoolisanimportantfactortosucceedinajob
# source: Ifwestudythemhard,wewillhavethechanceofdoingourjobbetterandquickerinthefuture
# <<C>> <<P>> <<positive>>
# target: studyinghardinschoolisanimportantfactortosucceedinajob
# source: ifsomeonewantstobecomeagoodindustrialengineer,heshouldstudyhistechnicalcoursesverywellsothathewillbeabletoutilizethemwellinhisfuturejob
# <<C>> <<P>> <<positive>>
# ID54
# ----------prediction results----------
# (79, 89, 7, 54, 74, 7, 2)
# target: everyonecanworkandliveinapeacefulenvironment
# source: alargeproportionofthetaxisspentonnationaldefenceandinmaintainingsocialst
# <<P>> <<P>> <<positive>>
# (13, 25, 6, 79, 89, 7, 2)
# target: allpeoplewhoareabletoworkshouldpaytaxtothegovernment
# source: everyonecanworkandliveinapeacefulenvironment
# <<C>> <<P>> <<positive>>
# (13, 25, 6, 91, 116, 7, 2)
# target: allpeoplewhoareabletoworkshouldpaytaxtothegovernment
# source: Thetaxisalsousedtopaythesalariesofworkersworkinginpublicservicesectors,suchasteachersandpoliceoffic
# <<C>> <<P>> <<positive>>
# (130, 143, 7, 120, 127, 7, 3)
# target: whattheydoisforthewell-beingofthewholesoc
# source: theseworkersdonotproduceprofitdirect
# <<P>> <<P>> <<negative>>
# (13, 25, 6, 130, 143, 7, 2)
# target: allpeoplewhoareabletoworkshouldpaytaxtothegovernment
# source: whattheydoisforthewell-beingofthewholesoc
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: everyonecanworkandliveinapeacefulenvironment
# source: alargeproportionofthetaxisspentonnationaldefenceandinmaintainingsocialst
# <<P>> <<P>> <<positive>>
# target: allpeoplewhoareabletoworkshouldpaytaxtothegovernment
# source: everyonecanworkandliveinapeacefulenvironment
# <<C>> <<P>> <<positive>>
# target: allpeoplewhoareabletoworkshouldpaytaxtothegovernment
# source: Thetaxisalsousedtopaythesalariesofworkersworkinginpublicservicesectors,suchasteachersandpoliceoffic
# <<C>> <<P>> <<positive>>
# target: Thetaxisalsousedtopaythesalariesofworkersworkinginpublicservicesectors,suchasteachersandpoliceoffic
# source: theseworkersdonotproduceprofitdirect
# <<P>> <<P>> <<negative>>
# target: theseworkersdonotproduceprofitdirect
# source: whattheydoisforthewell-beingofthewholesoc
# <<P>> <<P>> <<negative>>
# ID55
# ----------prediction results----------
# (16, 28, 6, 64, 85, 7, 2)
# target: exerciseplayacrucialroleinamelioratingphysicalhealth
# source: thesesportscanalsostrengthenmusclesandlessensurplusadiposetissuesinhumanbody
# <<C>> <<P>> <<positive>>
# (16, 28, 6, 98, 108, 7, 2)
# target: exerciseplayacrucialroleinamelioratingphysicalhealth
# source: nowadaysmoreandmorepeoplearesufferfromob
# <<C>> <<P>> <<positive>>
# (16, 28, 6, 111, 142, 7, 2)
# target: exerciseplayacrucialroleinamelioratingphysicalhealth
# source: Manystudieshaspointsoutthatnumbersofoverweightpeoplehaveincreasedindevelopedcountriesinrecentyears,whichmainlyresultsfrominsufficientex
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: exerciseplayacrucialroleinamelioratingphysicalhealth
# source: thesesportscanalsostrengthenmusclesandlessensurplusadiposetissuesinhumanbody
# <<C>> <<P>> <<positive>>
# target: exerciseplayacrucialroleinamelioratingphysicalhealth
# source: Thelatteroneisofparticularimportancebecausenowadaysmoreandmorepeoplearesufferfromob
# <<C>> <<P>> <<positive>>
# target: exerciseplayacrucialroleinamelioratingphysicalhealth
# source: Manystudieshaspointsoutthatnumbersofoverweightpeoplehaveincreasedindevelopedcountriesinrecentyears,whichmainlyresultsfrominsufficientex
# <<C>> <<P>> <<positive>>
# ID56
# ----------prediction results----------
# (130, 143, 6, 52, 96, 7, 2)
# target: itisverysignificanttofindanewplaceforlivinginotherplan
# source: In20thcentury,althoughhumanbeingsucceededtoachieveoutofspacebymeansofnewtechnologiessuchasrockets,butfindinganewplaceforlivinginanotherplanetisimpossibleuntilnow
# <<C>> <<P>> <<positive>>
# (130, 143, 6, 98, 125, 7, 2)
# target: itisverysignificanttofindanewplaceforlivinginotherplan
# source: Induringhistory,ourplanetisthreateningbymanyofotherplanetsorstarsanditisanenormousdangerforlivingofhuman
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: Manygovernmentsbelievethatspaceexplorationisanactivitythatwastesthebudget
# source: theessentialchallengeofhumanityinthefuturewouldbethediscoveryofanewplacefortheliving
# <<P>> <<P>> <<negative>>
# target: itisverysignificanttofindanewplaceforlivinginotherplan
# source: In20thcentury,althoughhumanbeingsucceededtoachieveoutofspacebymeansofnewtechnologiessuchasrockets,butfindinganewplaceforlivinginanotherplanetisimpossibleuntilnow
# <<C>> <<P>> <<positive>>
# target: itisverysignificanttofindanewplaceforlivinginotherplan
# source: Induringhistory,ourplanetisthreateningbymanyofotherplanetsorstarsanditisanenormousdangerforlivingofhuman
# <<C>> <<P>> <<positive>>
# ID57
# ----------prediction results----------
# (11, 33, 6, 73, 105, 7, 2)
# target: historicbuildingsmakeourlivesmorecolorful,provideplacesforcitizenstorelaxbodiesandmind
# source: thewarmthofthematerials,theheartpine,marble,ortheoldbrick,allthoseoldbuildingsfeaturescallbackofourinnerpeace
# <<C>> <<P>> <<positive>>
# (11, 33, 6, 107, 142, 7, 2)
# target: historicbuildingsmakeourlivesmorecolorful,provideplacesforcitizenstorelaxbodiesandmind
# source: Lyingundertheroofofahistoricbuildingorsittingonthedeskfillwithhistoryarebotheasywaystoforgetlife'slittleannoyanceandfeelpeace
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: historicbuildingsmakeourlivesmorecolorful,provideplacesforcitizenstorelaxbodiesandmind
# source: thewarmthofthematerials,theheartpine,marble,ortheoldbrick,allthoseoldbuildingsfeaturescallbackofourinnerpeace
# <<C>> <<P>> <<positive>>
# target: historicbuildingsmakeourlivesmorecolorful,provideplacesforcitizenstorelaxbodiesandmind
# source: Lyingundertheroofofahistoricbuildingorsittingonthedeskfillwithhistoryarebotheasywaystoforgetlife'slittleannoyanceandfeelpeace
# <<C>> <<P>> <<positive>>
# ID58
# ----------prediction results----------
# (11, 30, 6, 47, 73, 7, 2)
# target: themoreanadvertisementofaproducttakesplaceinmassmedia,themorepopulartheproductbec
# source: Consumerstendtopurchasethemostknownproductwhenitcomestopickingoneoutoftwodifferentbrandsofthesameproduct
# <<C>> <<P>> <<positive>>
# (11, 30, 6, 75, 98, 7, 2)
# target: themoreanadvertisementofaproducttakesplaceinmassmedia,themorepopulartheproductbec
# source: Whenaproductiscommonlyused,itbecomestrustworthyforthesociety,nomatterwhatqualityitis
# <<C>> <<P>> <<positive>>
# (11, 30, 6, 102, 111, 7, 2)
# target: themoreanadvertisementofaproducttakesplaceinmassmedia,themorepopulartheproductbec
# source: italsohastobeaffordablefortheconsumer
# <<C>> <<P>> <<positive>>
# (11, 30, 6, 117, 134, 7, 2)
# target: themoreanadvertisementofaproducttakesplaceinmassmedia,themorepopulartheproductbec
# source: advertisementshaveundeniableaffectsonthesocietyabouttheproductbeingadvert
# <<C>> <<P>> <<positive>>
# (11, 30, 6, 137, 141, 7, 2)
# target: themoreanadvertisementofaproducttakesplaceinmassmedia,themorepopulartheproductbec
# source: Theymaketheproductpre
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: Advertisementisthemosteffectivewaytocreateawell-knownproduct
# source: Consumerstendtopurchasethemostknownproductwhenitcomestopickingoneoutoftwodifferentbrandsofthesameproduct
# <<C>> <<P>> <<positive>>
# target: Theymaketheproductpre
# source: Whenaproductiscommonlyused,itbecomestrustworthyforthesociety,nomatterwhatqualityitis
# <<C>> <<P>> <<positive>>
# target: Whenaproductiscommonlyused,itbecomestrustworthyforthesociety,nomatterwhatqualityitis
# source: italsohastobeaffordablefortheconsumer
# <<P>> <<P>> <<negative>>
# target: Theymaketheproductpre
# source: advertisementshaveundeniableaffectsonthesocietyabouttheproductbeingadvert
# <<C>> <<P>> <<positive>>
# ID59
# ----------prediction results----------
# (50, 78, 7, 35, 45, 7, 2)
# target: thoselocalresidentshavetocleantheplacefrequentlysothatthenewbatchoftouristswillhaveatidyandneatenvironment
# source: somepeopleleavetherubbishaftervisitingtheatt
# <<P>> <<P>> <<positive>>
# (15, 31, 6, 50, 78, 7, 2)
# target: somebehaviorsofthetouristsarenotwelcomeinthelocalarea
# source: thoselocalresidentshavetocleantheplacefrequentlysothatthenewbatchoftouristswillhaveatidyandneatenvironment
# <<C>> <<P>> <<positive>>
# (118, 140, 6, 82, 96, 7, 2)
# target: iftouristswanttorespectthetradition,theywillnotorderanybeefinthelocalrest
# source: touristsmayoffendthelocalpeopleduetotheirdifferentculturebackground
# <<C>> <<P>> <<positive>>
# (118, 140, 6, 101, 107, 7, 2)
# target: iftouristswanttorespectthetradition,theywillnotorderanybeefinthelocalrest
# source: Indiansdon'teatbe
# <<C>> <<P>> <<positive>>
# (101, 107, 7, 110, 113, 7, 2)
# target: Indiansdon'teatbe
# source: theyworshipc
# <<P>> <<P>> <<positive>>
# ----------target results----------
# target: thenewbatchoftouristswillhaveatidyandneatenvironment
# source: thoselocalresidentshavetocleantheplacef
# <<P>> <<P>> <<positive>>
# target: somebehaviorsofthetouristsarenotwelcomeinthelocalarea
# source: thenewbatchoftouristswillhaveatidyandneatenvironment
# <<C>> <<P>> <<positive>>
# target: somebehaviorsofthetouristsarenotwelcomeinthelocalarea
# source: touristsmayoffendthelocalpeopleduetotheirdifferentculturebackground
# <<C>> <<P>> <<positive>>
# target: touristsmayoffendthelocalpeopleduetotheirdifferentculturebackground
# source: Indiansdon'teatbe
# <<P>> <<P>> <<positive>>
# target: Indiansdon'teatbe
# source: theyworshipc
# <<P>> <<P>> <<positive>>
# target: touristsmayoffendthelocalpeopleduetotheirdifferentculturebackground
# source: iftouristswanttorespectthetradition,theywillnotorderanybeefinthelocalrest
# <<P>> <<P>> <<positive>>
# ID60
# ----------prediction results----------
# (52, 63, 6, 65, 102, 7, 2)
# target: advertisingmayevenbringhealthiereatinghabitstothepeople
# source: Thinkabouttherecentlypopularorganicfoodsthatareclaimedtogrowinanenvironmentwithoutpesticideandthosecrudefoodsinwhichlesssaltorlesssugarareadded
# <<C>> <<P>> <<positive>>
# (127, 140, 6, 104, 121, 7, 2)
# target: theadvertisingindustrybolsterspeople'sawarenessofhavingahealthyl
# source: Thesearethemaintraitsthatadvertisingishittingonandtheoverallresultsaregood
# <<C>> <<P>> <<positive>>
# (52, 63, 6, 127, 140, 7, 2)
# target: advertisingmayevenbringhealthiereatinghabitstothepeople
# source: theadvertisingindustrybolsterspeople'sawarenessofhavingahealthyl
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: advertisingmayevenbringhealthiereatinghabitstothepeople
# source: Thinkabouttherecentlypopularorganicfoodsthatareclaimedtogrowinanenvironmentwithoutpesticideandthosecrudefoodsinwhichlesssaltorlesssugarareadded
# <<C>> <<P>> <<positive>>
# target: advertisingmayevenbringhealthiereatinghabitstothepeople
# source: Thesearethemaintraitsthatadvertisingishittingonandtheoverallresultsaregood
# <<C>> <<P>> <<positive>>
# target: advertisingmayevenbringhealthiereatinghabitstothepeople
# source: theadvertisingindustrybolsterspeople'sawarenessofhavingahealthyl
# <<C>> <<P>> <<positive>>
# ID61
# ----------prediction results----------
# (132, 140, 7, 44, 76, 7, 2)
# target: thenumberofthatproductbeingsoldwillincre
# source: Whentheconsumersareimpressedbythewayaproductisadvertised,theycanbeconvincedtoconsiderthattheproductisaneedinsomecases
# <<P>> <<P>> <<positive>>
# (132, 140, 7, 78, 95, 7, 2)
# target: thenumberofthatproductbeingsoldwillincre
# source: Recently,thereisaverycreativeadvertisementsofasoftdrinkproductonTV
# <<P>> <<P>> <<positive>>
# (132, 140, 7, 97, 124, 7, 2)
# target: thenumberofthatproductbeingsoldwillincre
# source: Thestorydeliversadesiredcalltodrinkthatsoftdrinkthatpeopletendtodrinkwhentheweatheristoohot
# <<P>> <<P>> <<positive>>
# (23, 42, 6, 132, 140, 7, 2)
# target: advertiserspushthelimitsofcreativitytodisposetheconsumerstopurchasetheproduct
# source: thenumberofthatproductbeingsoldwillincre
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: advertiserspushthelimitsofcreativitytodisposetheconsumerstopurchasetheproduct
# source: Whentheconsumersareimpressedbythewayaproductisadvertised,theycanbeconvincedtoconsiderthattheproductisaneedinsomecases
# <<C>> <<P>> <<positive>>
# target: thenumberofthatproductbeingsoldwillincre
# source: Recently,thereisaverycreativeadvertisementsofasoftdrinkproductonTV
# <<P>> <<P>> <<positive>>
# target: thenumberofthatproductbeingsoldwillincre
# source: Thestorydeliversadesiredcalltodrinkthatsoftdrinkthatpeopletendtodrinkwhentheweatheristoohot
# <<P>> <<P>> <<positive>>
# target: advertiserspushthelimitsofcreativitytodisposetheconsumerstopurchasetheproduct
# source: thenumberofthatproductbeingsoldwillincre
# <<C>> <<P>> <<positive>>
# ID62
# ----------prediction results----------
# (13, 30, 6, 67, 95, 7, 2)
# target: whenitcomestoknowledgeandtheacquisitionofsuch,classmatesaresecondtonone
# source: itcanbe,forexample,lessonsontheclass,socialskillsorgeneraletiquettesthataresometimesoverlookedbyparents
# <<C>> <<P>> <<positive>>
# (13, 30, 6, 97, 138, 7, 2)
# target: whenitcomestoknowledgeandtheacquisitionofsuch,classmatesaresecondtonone
# source: Sharingthesameage,childrenareattheirmostcomforttoexchangeideas,toqueryandinterpretabstractconceptswithoutfearofparentalpunishments,resultingindeepercom
# <<C>> <<P>> <<positive>>
# ----------target results----------
# target: whenitcomestoknowledgeandtheacquisitionofsuch,classmatesaresecondtonone
# source: itcanbe,forexample,lessonsontheclass,socialskillsorgeneraletiquettesthataresometimesoverlookedbyparents
# <<C>> <<P>> <<positive>>
# target: whenitcomestoknowledgeandtheacquisitionofsuch,classmatesaresecondtonone
# source: Sharingthesameage,childrenareattheirmostcomforttoexchangeideas,toqueryandinterpretabstractconceptswithoutfearofparentalpunishments,resultingindeepercom
# <<C>> <<P>> <<positive>>
# ID63
# ----------prediction results----------
# ----------target results----------
